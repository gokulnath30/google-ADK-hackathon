# %%
import os
from dotenv import load_dotenv
load_dotenv()
try:
    GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1, # Initial delay before first retry (in seconds)
    http_status_codes=[429, 500, 503, 504] # Retry on these HTTP errors
)
root_agent = Agent(
    name="helpful_assistant",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)
runner = InMemoryRunner(agent=root_agent)

print("✅ Root Agent defined.")
# Out:
# ✅ Root Agent defined.

# %%
response = await runner.run_debug(
    "Can you show in 2024 income in tamil nadu district wise?"
)
# Out:
#  ### Continue session: debug_session_id
#
# User > Can you show in 2024 income in tamil nadu district wise?
# helpful_assistant > I cannot provide district-wise income data for Tamil Nadu for the year 2024, as this specific data is not yet available. However, I can offer information based on the latest available data, which is from 2019-20, and projections for 2024-25.
#
# **Key findings from the latest available data (2019-20) and projections for 2024-25:**
#
# *   **State Average:** In 2019-20, the per capita income in Tamil Nadu was ₹2,36,783. For 2021-22, it was ₹2.42 lakh. Projections for 2025 estimate the per capita income to be $5,432 (nominal).
# *   **District-wise Variations:** There are significant variations in per capita income across districts.
#     *   **Highest Per Capita Income:** In 2019-20, Tiruvallur had the highest per capita income at around ₹3.64 lakh, followed by Erode (₹3.57 lakh) and Coimbatore (₹3.39 lakh). Another report for 2019-20 states Thiruvallur at ₹3.67 lakh. For an older report (likely pre-2020), Kanyakumari was reported as the richest district with ₹81,094 per capita income, followed by Tirupur and Tiruvallur.
#     *   **Lowest Per Capita Income:** Perambalur had the lowest per capita income at ₹1,07,731 in 2019-20. Other districts with lower per capita income include Tiruvarur (₹1,25,653) and Villupuram (₹1,30,103) in 2019-20.
# *   **Districts Below State Average:** As of 2019-20, 19 districts had a per capita income lower than the state average.
# *   **Economic Growth:** Tamil Nadu's economy has shown robust growth. For 2024-25, it is projected to achieve a real economic growth rate of 9.69%, which is the highest among all Indian states. The state's Gross State Domestic Product (GSDP) at current prices reached ₹27.22 lakh crore in 2023-24. The state aims to become a $1 trillion economy by 2030.
#
# For more detailed district-wise income data, you would need to refer to official reports from the Tamil Nadu Department of Economics and Statistics or the Economic Survey of Tamil Nadu when it becomes available for the relevant years.
